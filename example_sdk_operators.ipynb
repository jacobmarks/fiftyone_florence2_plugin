# %%
# !pip install fiftyone transformers<=4.49 torch einops timm accelerate

# %%
import os
os.environ['FIFTYONE_ALLOW_LEGACY_ORCHESTRATORS'] = 'true'

# %%
import fiftyone.zoo as foz
import fiftyone as fo

dataset = foz.load_zoo_dataset("quickstart")

smol_ds = dataset.take(10).clone(name="smol_qs")
# Out:
# Dataset already downloaded
# Loading existing dataset 'quickstart'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use

# %% [markdown]
# # Captioning
#
# The Florence2 captioning operator can run in three different detail levels:
#
# 1. **Basic** - This is the default mode, generating simple captions for images
# 2. **Detailed** - Provides more comprehensive image descriptions
# 3. **More Detailed** - Offers the most extensive and detailed image captions
#
#
# Each detail level progressively provides more information in the generated captions, allowing you to choose the appropriate level of description for your use case.
#
#
# The operator uses the Microsoft `Florence-2-base-ft` model and allows you to specify the output field name where the captions will be stored in your FiftyOne dataset. You can run the operator like this:

# %%
import fiftyone.operators as foo

MODEL_PATH ="microsoft/Florence-2-base-ft"

florence2_captioning = foo.get_operator("@jacobmarks/florence2/caption_with_florence2")
# Out:
# Python version is above 3.10, patching the collections module.
# /home/harpreet/miniconda3/envs/fiftyone/lib/python3.11/site-packages/transformers/models/auto/image_processing_auto.py:595: FutureWarning: The image_processor_class argument is deprecated and will be removed in v4.42. Please use `slow_image_processor_class`, or `fast_image_processor_class` instead
#   warnings.warn(

# %% [markdown]
# When running in a notebook you follow these steps:
#
# 1) Ensure that you have set the environment variable `os.environ['FIFTYONE_ALLOW_LEGACY_ORCHESTRATORS'] = 'true'`
#
# 2) Kick off a [Delegated Service](https://beta-docs.voxel51.com/cli/#fiftyone-delegated-operations) by opening your terminal and executing `fiftyone delegated launch`
#
# 3) Use the `await` syntax and pass `delegate=True` into your operator calls.

# %%
await florence2_captioning(
    smol_ds,
    model_path=MODEL_PATH,
    detail_level="basic",
    output_field="basic_caption",
    delegate=True
    )

# %%
smol_ds.first()['basic_caption']
# Out:
# 'A herd of zebra standing on top of a lush green field.'

# %%
await florence2_captioning(
    smol_ds,
    model_path=MODEL_PATH,
    detail_level="detailed",
    output_field="detailed_caption",
    )

# %%
smol_ds.first()['detailed_caption']
# Out:
# 'In this image we can see zebras on the ground. In the background there are trees.'

# %%
await florence2_captioning(
    smol_ds,
    model_path=MODEL_PATH,
    detail_level="more_detailed",
    output_field="more_detailed_caption",
    )

# %%
smol_ds.first()['more_detailed_caption']
# Out:
# 'There are several zebras standing in a field. There is tall grass under them. There are trees behind them in the distance. '

# %% [markdown]
# # Phrase Grounding
#
# The Florence2 phrase grounding operator allows you to locate specific phrases within an image. It can be run in two ways:
#
# 1. Using an existing caption field in your dataset by specifying the `caption_field` parameter
#
# 2. Using a direct caption input by providing the `caption` parameter
#
# The operator will analyze the image and attempt to locate/ground the phrases from the caption within the image. This is particularly useful for tasks where you need to identify and locate specific objects or elements mentioned in image captions.
#
# You can run it like this:

# %%
import fiftyone.operators as foo

MODEL_PATH ="microsoft/Florence-2-base-ft"

florence2_phrase_grounding = foo.get_operator("@jacobmarks/florence2/caption_to_phrase_grounding_with_florence2")

# %%
# Using a caption field
await florence2_phrase_grounding(
    smol_ds,
    model_path=MODEL_PATH,
    caption_field="detailed_caption", #must be a field on your dataset
    output_field="phrase_grounding_caption_field",
    delegate=True
)

# %%
smol_ds.first()['phrase_grounding_caption_field']
# Out:
# <Detections: {
#     'detections': [
#         <Detection: {
#             'id': '67e1cd03b161a758312e0ce9',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebras',
#             'bounding_box': [
#                 0.3014999866485596,
#                 0.22850000063578288,
#                 0.696999979019165,
#                 0.6650000095367432,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd03b161a758312e0cea',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebras',
#             'bounding_box': [
#                 0.47149996757507323,
#                 0.2634999910990397,
#                 0.2740000247955322,
#                 0.6249999682108561,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd03b161a758312e0ceb',
#             'attributes': {},
#             'tags': [],
#             'label': 'trees',
#             'bounding_box': [
#                 0.0004999999888241291,
#                 0.0004999999888241291,
#                 0.9979999656789005,
#                 0.21200000001117586,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#     ],
# }>

# %%
await florence2_phrase_grounding(
    smol_ds,
    model_path=MODEL_PATH,
    caption="A cat sitting on a couch", #open text caption
    output_field="phrase_grounding_open_text",
    delegate=True
)

# %%
smol_ds.first()['phrase_grounding_caption_field']
# Out:
# <Detections: {
#     'detections': [
#         <Detection: {
#             'id': '67e1cd03b161a758312e0ce9',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebras',
#             'bounding_box': [
#                 0.3014999866485596,
#                 0.22850000063578288,
#                 0.696999979019165,
#                 0.6650000095367432,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd03b161a758312e0cea',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebras',
#             'bounding_box': [
#                 0.47149996757507323,
#                 0.2634999910990397,
#                 0.2740000247955322,
#                 0.6249999682108561,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd03b161a758312e0ceb',
#             'attributes': {},
#             'tags': [],
#             'label': 'trees',
#             'bounding_box': [
#                 0.0004999999888241291,
#                 0.0004999999888241291,
#                 0.9979999656789005,
#                 0.21200000001117586,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#     ],
# }>

# %% [markdown]
# # Detection
#
# The Florence2 detection operator can run in four different modes:
#
# 1. **Detection** (default) - Standard object detection
# 2. **Dense Region Caption** - Generates captions for different regions in the image
# 3. **Region Proposal** - Suggests regions of interest in the image
# 4. **Open Vocabulary Detection** - Allows detection of objects specified by a text prompt
#
# Each mode serves a different purpose in analyzing and understanding the content of images, with open vocabulary detection being particularly flexible as it allows you to specify what objects you want to detect through text prompts, though the model only supports *detecting one class through open vocabulary detection*.
#
# You can run the operator like this:

# %%
import fiftyone.operators as foo

MODEL_PATH ="microsoft/Florence-2-base-ft"

florence2_detection = foo.get_operator("@jacobmarks/florence2/detect_with_florence2")

# %%
await florence2_detection(
    smol_ds,
    model_path=MODEL_PATH,
    detection_type="detection",
    output_field="standard_detection",
    delegate=True
)

# %%
smol_ds.first()['standard_detection']
# Out:
# <Detections: {
#     'detections': [
#         <Detection: {
#             'id': '67e1cd20b161a758312e0d4f',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebra',
#             'bounding_box': [
#                 0.3044999837875366,
#                 0.2654999891916911,
#                 0.44100000858306887,
#                 0.6289999802907308,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd20b161a758312e0d50',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebra',
#             'bounding_box': [
#                 0.47149996757507323,
#                 0.2654999891916911,
#                 0.27300000190734863,
#                 0.6269999980926514,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd20b161a758312e0d51',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebra',
#             'bounding_box': [
#                 0.3044999837875366,
#                 0.26749998728434243,
#                 0.25299999713897703,
#                 0.625,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd20b161a758312e0d52',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebra',
#             'bounding_box': [
#                 0.34149999618530275,
#                 0.29249998728434246,
#                 0.1549999713897705,
#                 0.6019999821980794,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd20b161a758312e0d53',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebra',
#             'bounding_box': [
#                 0.5714999675750733,
#                 0.23849999109903972,
#                 0.15900001525878907,
#                 0.15399999618530275,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd20b161a758312e0d54',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebra',
#             'bounding_box': [
#                 0.8064999580383301,
#                 0.24749999046325682,
#                 0.1640000343322754,
#                 0.14100000063578289,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd20b161a758312e0d55',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebra',
#             'bounding_box': [
#                 0.947499942779541,
#                 0.23649999300638835,
#                 0.051000022888183595,
#                 0.15400001207987468,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#     ],
# }>

# %%
await florence2_detection(
    smol_ds,
    model_path=MODEL_PATH,
    detection_type="dense_region_caption",
    output_field="dense_region_detection",
    delegate=True
)

# %%
smol_ds.first()['dense_region_detection']
# Out:
# <Detections: {
#     'detections': [
#         <Detection: {
#             'id': '67e1cd3eb161a758312e0dd7',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebra',
#             'bounding_box': [
#                 0.3044999837875366,
#                 0.26749998728434243,
#                 0.37299997806549073,
#                 0.621999994913737,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd3eb161a758312e0dd8',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebra',
#             'bounding_box': [
#                 0.47049999237060547,
#                 0.2654999891916911,
#                 0.2739999771118164,
#                 0.625000015894572,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd3eb161a758312e0dd9',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebra',
#             'bounding_box': [
#                 0.34149999618530275,
#                 0.29249998728434246,
#                 0.1559999942779541,
#                 0.6019999821980794,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd3eb161a758312e0dda',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebra',
#             'bounding_box': [
#                 0.5724999904632568,
#                 0.23849999109903972,
#                 0.15799999237060547,
#                 0.15399999618530275,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd3eb161a758312e0ddb',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebra',
#             'bounding_box': [
#                 0.8064999580383301,
#                 0.24749999046325682,
#                 0.1630000114440918,
#                 0.14100000063578289,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd3eb161a758312e0ddc',
#             'attributes': {},
#             'tags': [],
#             'label': 'zebra',
#             'bounding_box': [
#                 0.947499942779541,
#                 0.23649999300638835,
#                 0.051000022888183595,
#                 0.15400001207987468,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#     ],
# }>

# %%
await florence2_detection(
    smol_ds,
    model_path=MODEL_PATH,
    detection_type="region_proposal",
    output_field="region_proposals",
    delegate=True
)

# %%
smol_ds.first()['region_proposals']
# Out:
# <Detections: {
#     'detections': [
#         <Detection: {
#             'id': '67e1cd57b161a758312e0e37',
#             'attributes': {},
#             'tags': [],
#             'label': 'object_1',
#             'bounding_box': [
#                 0.3044999837875366,
#                 0.23649999300638835,
#                 0.693999981880188,
#                 0.6579999764760335,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd57b161a758312e0e38',
#             'attributes': {},
#             'tags': [],
#             'label': 'object_2',
#             'bounding_box': [
#                 0.3044999837875366,
#                 0.26649999618530273,
#                 0.37299997806549073,
#                 0.6229999860127767,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd57b161a758312e0e39',
#             'attributes': {},
#             'tags': [],
#             'label': 'object_3',
#             'bounding_box': [
#                 0.47249999046325686,
#                 0.2654999891916911,
#                 0.27199997901916506,
#                 0.625000015894572,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd57b161a758312e0e3a',
#             'attributes': {},
#             'tags': [],
#             'label': 'object_4',
#             'bounding_box': [
#                 0.34149999618530275,
#                 0.29149999618530276,
#                 0.15799999237060547,
#                 0.6029999732971192,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd57b161a758312e0e3b',
#             'attributes': {},
#             'tags': [],
#             'label': 'object_5',
#             'bounding_box': [
#                 0.8064999580383301,
#                 0.23649999300638835,
#                 0.19200000762939454,
#                 0.15400001207987468,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd57b161a758312e0e3c',
#             'attributes': {},
#             'tags': [],
#             'label': 'object_6',
#             'bounding_box': [
#                 0.5734999656677247,
#                 0.23849999109903972,
#                 0.1559999942779541,
#                 0.15300000508626302,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd57b161a758312e0e3d',
#             'attributes': {},
#             'tags': [],
#             'label': 'object_7',
#             'bounding_box': [
#                 0.8064999580383301,
#                 0.24649999936421713,
#                 0.14099998474121095,
#                 0.14100000063578289,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#         <Detection: {
#             'id': '67e1cd57b161a758312e0e3e',
#             'attributes': {},
#             'tags': [],
#             'label': 'object_8',
#             'bounding_box': [
#                 0.947499942779541,
#                 0.23649999300638835,
#                 0.051000022888183595,
#                 0.15299998919169108,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#     ],
# }>

# %%
await florence2_detection(
    smol_ds,
    model_path=MODEL_PATH,
    detection_type="open_vocabulary_detection",
    text_prompt = "pedestrains", # the object you want to detect
    output_field="open_detection",
    delegate=True
)

# %%
smol_ds.first()['open_detection']
# Out:
# <Detections: {'detections': []}>

# %% [markdown]
# # Referring Segmentation
#
# The Florence2 segmentation operator performs referring expression segmentation, which allows you to segment specific regions in an image based on natural language descriptions.
#
# This is particularly useful when you need to segment specific parts of an image based on textual descriptions, allowing for precise region identification using natural language.
# It can be used in two ways:
#
# 1. Using a direct expression through the `expression` parameter
#
# 2. Using an existing expression field in your dataset via the `expression_field` parameter
#
# You can run the operator like this:

# %%
import fiftyone.operators as foo

MODEL_PATH ="microsoft/Florence-2-base-ft"

florence2_referring_segmentation = foo.get_operator("@jacobmarks/florence2/referring_expression_segmentation_with_florence2")

# %%
await florence2_referring_segmentation(
    smol_ds,
    model_path=MODEL_PATH,
    expression_field="basic_caption", #must be a field on your dataset
    output_field="expression_field_segmentations",
    delegate=True
)

# %%
smol_ds.first()['expression_field_segmentations']
# Out:
# <Polylines: {
#     'polylines': [
#         <Polyline: {
#             'id': '67e1cd9cb161a758312e0e73',
#             'attributes': {},
#             'tags': [],
#             'label': 'object_1',
#             'points': [
#                 [
#                     [0.49049997329711914, 0.2684999783833822],
#                     [0.4994999885559082, 0.2684999783833822],
#                     [0.4994999885559082, 0.2684999783833822],
#                     [0.5105000019073487, 0.2684999783833822],
#                     [0.5105000019073487, 0.2684999783833822],
#                     [0.5204999923706055, 0.2684999783833822],
#                     [0.5204999923706055, 0.2684999783833822],
#                     [0.5295000076293945, 0.2684999783833822],
#                     [0.5295000076293945, 0.2684999783833822],
#                     [0.5384999752044678, 0.2684999783833822],
#                     [0.5384999752044678, 0.2684999783833822],
#                     [0.5484999656677246, 0.2684999783833822],
#                     [0.5484999656677246, 0.2684999783833822],
#                     [0.5574999809265136, 0.2684999783833822],
#                     [0.5574999809265136, 0.27549997965494794],
#                     [0.559499979019165, 0.27549997965494794],
#                     [0.559499979019165, 0.2875],
#                     [0.559499979019165, 0.2875],
#                     [0.559499979019165, 0.2994999885559082],
#                     [0.559499979019165, 0.2994999885559082],
#                     [0.559499979019165, 0.3085000038146973],
#                     [0.559499979019165, 0.3085000038146973],
#                     [0.559499979019165, 0.315500005086263],
#                     [0.5664999961853028, 0.315500005086263],
#                     [0.5664999961853028, 0.315500005086263],
#                     [0.5754999637603759, 0.315500005086263],
#                     [0.5754999637603759, 0.3085000038146973],
#                     [0.5855000019073486, 0.3085000038146973],
#                     [0.5855000019073486, 0.30649998982747395],
#                     [0.5944999694824219, 0.30649998982747395],
#                     [0.5944999694824219, 0.30649998982747395],
#                     [0.5964999675750733, 0.30649998982747395],
#                     [0.5964999675750733, 0.30649998982747395],
#                     [0.5964999675750733, 0.30649998982747395],
#                     [0.5964999675750733, 0.315500005086263],
#                     [0.5944999694824219, 0.315500005086263],
#                     [0.5944999694824219, 0.32749999364217125],
#                     [0.5894999980926514, 0.32749999364217125],
#                     [0.5894999980926514, 0.34149999618530275],
#                     [0.5855000019073486, 0.34149999618530275],
#                     [0.5855000019073486, 0.35549999872843424],
#                     [0.5855000019073486, 0.35549999872843424],
#                     [0.5855000019073486, 0.36950000127156574],
#                     [0.5855000019073486, 0.36950000127156574],
#                     [0.5855000019073486, 0.3835000038146973],
#                     [0.5855000019073486, 0.3835000038146973],
#                     [0.5855000019073486, 0.3975000063578288],
#                     [0.5855000019073486, 0.3975000063578288],
#                     [0.5855000019073486, 0.4114999771118164],
#                     [0.5855000019073486, 0.4114999771118164],
#                     [0.5855000019073486, 0.4234999974568685],
#                     [0.5855000019073486, 0.4234999974568685],
#                     [0.5855000019073486, 0.43049999872843425],
#                     [0.5855000019073486, 0.43049999872843425],
#                     [0.5855000019073486, 0.43049999872843425],
#                     [0.5964999675750733, 0.43049999872843425],
#                     [0.5964999675750733, 0.4234999974568685],
#                     [0.6054999828338623, 0.4234999974568685],
#                     [0.6054999828338623, 0.41649999618530276],
#                     [0.6174999713897705, 0.41649999618530276],
#                     [0.6174999713897705, 0.40949999491373695],
#                     [0.6315000057220459, 0.40949999491373695],
#                     [0.6315000057220459, 0.40449997584025066],
#                     [0.6454999923706055, 0.40449997584025066],
#                     [0.6454999923706055, 0.40449997584025066],
#                     [0.659499979019165, 0.40449997584025066],
#                     [0.659499979019165, 0.40449997584025066],
#                     [0.6734999656677246, 0.40449997584025066],
#                     [0.6734999656677246, 0.40449997584025066],
#                     [0.6875, 0.40449997584025066],
#                     [0.6875, 0.40949999491373695],
#                     [0.7014999866485596, 0.40949999491373695],
#                     [0.7014999866485596, 0.41649999618530276],
#                     [0.7154999732971191, 0.41649999618530276],
#                     [0.7154999732971191, 0.4254999796549479],
#                     [0.7274999618530273, 0.4254999796549479],
#                     [0.7274999618530273, 0.4375],
#                     [0.7364999771118164, 0.4375],
#                     [0.7364999771118164, 0.4515000025431315],
#                     [0.7414999961853027, 0.4515000025431315],
#                     [0.7414999961853027, 0.46550000508626305],
#                     [0.7454999923706055, 0.46550000508626305],
#                     [0.7454999923706055, 0.4864999771118164],
#                     [0.7454999923706055, 0.4864999771118164],
#                     [0.7454999923706055, 0.5054999987284342],
#                     [0.7454999923706055, 0.5054999987284342],
#                     [0.7454999923706055, 0.5265000025431316],
#                     [0.7454999923706055, 0.5265000025431316],
#                     [0.7454999923706055, 0.5474999745686849],
#                     [0.7454999923706055, 0.5474999745686849],
#                     [0.7454999923706055, 0.568500010172526],
#                     [0.7454999923706055, 0.568500010172526],
#                     [0.7454999923706055, 0.5894999821980794],
#                     [0.7454999923706055, 0.5894999821980794],
#                     [0.7454999923706055, 0.6105000178019205],
#                     [0.7454999923706055, 0.6105000178019205],
#                     [0.7454999923706055, 0.6295000076293945],
#                     [0.7454999923706055, 0.6295000076293945],
#                     [0.7454999923706055, 0.6504999796549479],
#                     [0.7454999923706055, 0.6504999796549479],
#                     [0.7454999923706055, 0.6715000152587891],
#                     [0.7454999923706055, 0.6715000152587891],
#                     [0.7454999923706055, 0.6924999872843425],
#                     [0.7454999923706055, 0.6924999872843425],
#                     [0.7454999923706055, 0.7134999593098958],
#                     [0.7454999923706055, 0.7134999593098958],
#                     [0.7454999923706055, 0.7394999821980794],
#                     [0.7454999923706055, 0.7394999821980794],
#                     [0.7454999923706055, 0.7604999542236328],
#                     [0.7454999923706055, 0.7604999542236328],
#                     [0.7454999923706055, 0.7814999898274739],
#                     [0.7454999923706055, 0.7814999898274739],
#                     [0.7454999923706055, 0.8024999618530273],
#                     [0.7454999923706055, 0.8024999618530273],
#                     [0.7454999923706055, 0.8214999516805013],
#                     [0.7454999923706055, 0.8214999516805013],
#                     [0.7454999923706055, 0.8375],
#                     [0.7454999923706055, 0.8375],
#                     [0.7454999923706055, 0.8515000025431315],
#                     [0.7454999923706055, 0.8515000025431315],
#                     [0.7454999923706055, 0.8634999593098959],
#                     [0.7414999961853027, 0.8634999593098959],
#                     [0.7414999961853027, 0.8704999923706055],
#                     [0.7344999790191651, 0.8704999923706055],
#                     [0.7344999790191651, 0.8704999923706055],
#                     [0.7224999904632569, 0.8704999923706055],
#                     [0.7224999904632569, 0.8704999923706055],
#                     [0.7134999752044677, 0.8704999923706055],
#                     [0.7134999752044677, 0.8704999923706055],
#                     [0.7034999847412109, 0.8704999923706055],
#                     [0.7034999847412109, 0.8704999923706055],
#                     [0.6944999694824219, 0.8704999923706055],
#                     [0.6944999694824219, 0.8704999923706055],
#                     [0.6875, 0.8704999923706055],
#                     [0.6875, 0.8704999923706055],
#                     [0.6824999809265136, 0.8704999923706055],
#                     [0.6824999809265136, 0.8704999923706055],
#                     [0.678499984741211, 0.8704999923706055],
#                     [0.678499984741211, 0.8704999923706055],
#                     [0.678499984741211, 0.8704999923706055],
#                     [0.678499984741211, 0.8634999593098959],
#                     [0.678499984741211, 0.8634999593098959],
#                     [0.678499984741211, 0.8515000025431315],
#                     [0.678499984741211, 0.8515000025431315],
#                     [0.678499984741211, 0.8375],
#                     [0.678499984741211, 0.8375],
#                     [0.678499984741211, 0.8214999516805013],
#                     [0.678499984741211, 0.8214999516805013],
#                     [0.678499984741211, 0.8075000127156575],
#                     [0.678499984741211, 0.8075000127156575],
#                     [0.678499984741211, 0.793500010172526],
#                     [0.678499984741211, 0.793500010172526],
#                     [0.678499984741211, 0.7795000076293945],
#                     [0.678499984741211, 0.7795000076293945],
#                     [0.678499984741211, 0.7625],
#                     [0.678499984741211, 0.7625],
#                     [0.678499984741211, 0.7464999516805013],
#                     [0.678499984741211, 0.7464999516805013],
#                     [0.678499984741211, 0.7325000127156576],
#                     [0.678499984741211, 0.7325000127156576],
#                     [0.678499984741211, 0.7204999923706055],
#                     [0.678499984741211, 0.7204999923706055],
#                     [0.678499984741211, 0.706499989827474],
#                     [0.678499984741211, 0.706499989827474],
#                     [0.678499984741211, 0.6924999872843425],
#                     [0.678499984741211, 0.6924999872843425],
#                     [0.678499984741211, 0.678499984741211],
#                     [0.678499984741211, 0.678499984741211],
#                     [0.678499984741211, 0.6664999643961589],
#                     [0.678499984741211, 0.6664999643961589],
#                     [0.678499984741211, 0.6524999618530274],
#                     [0.678499984741211, 0.6524999618530274],
#                     [0.678499984741211, 0.6454999923706055],
#                     [0.678499984741211, 0.6454999923706055],
#                     [0.678499984741211, 0.6454999923706055],
#                     [0.6714999675750732, 0.6454999923706055],
#                     [0.6714999675750732, 0.6454999923706055],
#                     [0.6714999675750732, 0.6454999923706055],
#                     [0.6714999675750732, 0.6524999618530274],
#                     [0.6714999675750732, 0.6524999618530274],
#                     [0.6714999675750732, 0.6664999643961589],
#                     [0.6714999675750732, 0.6664999643961589],
#                     [0.6714999675750732, 0.678499984741211],
#                     [0.6714999675750732, 0.678499984741211],
#                     [0.6714999675750732, 0.6924999872843425],
#                     [0.6714999675750732, 0.6924999872843425],
#                     [0.6714999675750732, 0.706499989827474],
#                     [0.6714999675750732, 0.706499989827474],
#                     [0.6714999675750732, 0.7204999923706055],
#                     [0.6714999675750732, 0.7204999923706055],
#                     [0.6714999675750732, 0.7325000127156576],
#                     [0.6714999675750732, 0.7325000127156576],
#                     [0.6714999675750732, 0.7464999516805013],
#                     [0.6714999675750732, 0.7464999516805013],
#                     [0.6714999675750732, 0.7625],
#                     [0.6714999675750732, 0.7625],
#                     [0.6714999675750732, 0.7795000076293945],
#                     [0.6714999675750732, 0.7795000076293945],
#                     [0.6714999675750732, 0.793500010172526],
#                     [0.6714999675750732, 0.793500010172526],
#                     [0.6714999675750732, 0.8075000127156575],
#                     [0.6714999675750732, 0.8075000127156575],
#                     [0.6714999675750732, 0.8214999516805013],
#                     [0.6714999675750732, 0.8214999516805013],
#                     [0.6714999675750732, 0.8375],
#                     [0.6714999675750732, 0.8375],
#                     [0.6714999675750732, 0.8515000025431315],
#                     [0.6714999675750732, 0.8515000025431315],
#                     [0.6714999675750732, 0.8634999593098959],
#                     [0.6714999675750732, 0.8634999593098959],
#                     [0.6714999675750732, 0.8724999745686849],
#                     [0.6714999675750732, 0.8724999745686849],
#                     [0.6714999675750732, 0.884499994913737],
#                     [0.6714999675750732, 0.884499994913737],
#                     [0.6714999675750732, 0.8914999643961589],
#                     [0.6714999675750732, 0.8914999643961589],
#                     [0.6714999675750732, 0.8984999974568685],
#                     [0.6714999675750732, 0.8984999974568685],
#                     [0.6714999675750732, 0.9054999669392904],
#                     [0.6714999675750732, 0.9054999669392904],
#                     [0.6714999675750732, 0.9125],
#                     [0.6714999675750732, 0.9125],
#                     [0.6714999675750732, 0.9194999694824219],
#                     [0.6714999675750732, 0.9194999694824219],
#                     [0.6714999675750732, 0.931499989827474],
#                     [0.6714999675750732, 0.931499989827474],
#                     [0.6714999675750732, 0.940500005086263],
#                     [0.6714999675750732, 0.940500005086263],
#                     [0.6714999675750732, 0.9524999618530273],
#                     [0.6714999675750732, 0.9524999618530273],
#                     [0.6714999675750732, 0.9614999771118165],
#                     [0.6714999675750732, 0.9614999771118165],
#                     [0.6714999675750732, 0.9734999974568684],
#                     [0.6714999675750732, 0.9734999974568684],
#                     [0.6714999675750732, 0.9854999542236328],
#                     [0.6714999675750732, 0.9854999542236328],
#                     [0.6714999675750732, 0.9994999567667643],
#                     [0.6714999675750732, 0.9994999567667643],
#                     [0.6714999675750732, 0.9994999567667643],
#                     [0.0004999999888241291, 0.9994999567667643],
#                     [0.0004999999888241291, 0.9994999567667643],
#                     [0.0004999999888241291, 0.9994999567667643],
#                     [0.0004999999888241291, 0.9974999745686849],
#                     [0.0004999999888241291, 0.9974999745686849],
#                     [0.0004999999888241291, 0.9994999567667643],
#                     [0.0014999999664723873, 0.9994999567667643],
#                     [0.0014999999664723873, 0.9994999567667643],
#                     [0.0004999999888241291, 0.9994999567667643],
#                     [0.0004999999888241291, 0.9944999694824219],
#                     [0.0004999999888241291, 0.9944999694824219],
#                     [0.0004999999888241291, 0.9944999694824219],
#                     [0.0014999999664723873, 0.9944999694824219],
#                     [0.0014999999664723873, 0.9944999694824219],
#                     [0.0014999999664723873, 0.9944999694824219],
#                     [0.0014999999664723873, 0.9994999567667643],
#                     [0.0014999999664723873, 0.9994999567667643],
#                     [0.0014999999664723873, 0.9974999745686849],
#                     [0.0014999999664723873, 0.9974999745686849],
#                     [0.0014999999664723873, 0.9944999694824219],
#                     [0.0004999999888241291, 0.9944999694824219],
#                     [0.0004999999888241291, 0.9924999872843424],
#                     [0.0004999999888241291, 0.9924999872843424],
#                     [0.0004999999888241291, 0.9924999872843424],
#                     [0.0014999999664723873, 0.9924999872843424],
#                     [0.0014999999664723873, 0.9924999872843424],
#                     [0.003500000014901161, 0.9924999872843424],
#                     [0.003500000014901161, 0.9924999872843424],
#                     [0.010499999672174454, 0.9924999872843424],
#                     [0.010499999672174454, 0.9924999872843424],
#                     [0.01550000011920929, 0.9924999872843424],
#                     [0.01550000011920929, 0.9924999872843424],
#                     [0.02249999940395355, 0.9924999872843424],
#                     [0.02249999940395355, 0.9924999872843424],
#                     [0.029499998688697814, 0.9924999872843424],
#                     [0.029499998688697814, 0.9924999872843424],
#                     [0.036499997973442076, 0.9924999872843424],
#                     [0.036499997973442076, 0.9924999872843424],
#                     [0.04549999833106995, 0.9924999872843424],
#                     [0.04549999833106995, 0.9924999872843424],
#                     [0.05249999761581421, 0.9924999872843424],
#                     [0.05249999761581421, 0.9924999872843424],
#                     [0.059499996900558474, 0.9924999872843424],
#                     [0.059499996900558474, 0.9924999872843424],
#                     [0.06649999618530274, 0.9924999872843424],
#                     [0.06649999618530274, 0.9924999872843424],
#                     [0.07549999952316284, 0.9924999872843424],
#                     [0.07549999952316284, 0.9924999872843424],
#                     [0.08249999880790711, 0.9924999872843424],
#                     [0.08249999880790711, 0.9924999872843424],
#                     [0.08949999809265137, 0.9924999872843424],
#                     [0.08949999809265137, 0.9924999872843424],
#                     [0.09649999737739563, 0.9924999872843424],
#                     [0.09649999737739563, 0.9924999872843424],
#                     [0.1034999966621399, 0.9924999872843424],
#                     [0.1034999966621399, 0.9924999872843424],
#                     [0.11050000190734863, 0.9924999872843424],
#                     [0.11050000190734863, 0.9924999872843424],
#                     [0.11949999332427978, 0.9924999872843424],
#                     [0.11949999332427978, 0.9924999872843424],
#                     [0.1284999966621399, 0.9924999872843424],
#                     [0.1284999966621399, 0.9924999872843424],
#                     [0.13849999904632568, 0.9924999872843424],
#                     [0.13849999904632568, 0.9924999872843424],
#                     [0.14750000238418579, 0.9924999872843424],
#                     [0.14750000238418579, 0.9924999872843424],
#                     [0.15449999570846557, 0.9924999872843424],
#                     [0.15449999570846557, 0.9924999872843424],
#                     [0.16349999904632567, 0.9924999872843424],
#                     [0.16349999904632567, 0.9924999872843424],
#                     [0.17049999237060548, 0.9924999872843424],
#                     [0.17049999237060548, 0.9924999872843424],
#                     [0.1774999976158142, 0.9924999872843424],
#                     [0.1774999976158142, 0.9924999872843424],
#                     [0.184499990940094, 0.9924999872843424],
#                     [0.184499990940094, 0.9924999872843424],
#                     [0.19149999618530272, 0.9924999872843424],
#                     [0.19149999618530272, 0.9924999872843424],
#                     [0.2004999876022339, 0.9924999872843424],
#                     [0.2004999876022339, 0.9924999872843424],
#                     [0.20950000286102294, 0.9924999872843424],
#                     [0.20950000286102294, 0.9924999872843424],
#                     [0.21949999332427977, 0.9924999872843424],
#                     [0.21949999332427977, 0.9924999872843424],
#                     [0.22849998474121094, 0.9924999872843424],
#                     [0.22849998474121094, 0.9924999872843424],
#                     [0.2375, 0.9924999872843424],
#                     [0.2375, 0.9924999872843424],
#                     [0.24649999141693116, 0.9924999872843424],
#                     [0.24649999141693116, 0.9924999872843424],
#                     [0.2565000057220459, 0.9924999872843424],
#                     [0.2565000057220459, 0.9924999872843424],
#                     [0.26549999713897704, 0.9924999872843424],
#                     [0.26549999713897704, 0.9924999872843424],
#                     [0.2744999885559082, 0.9924999872843424],
#                     [0.2744999885559082, 0.9924999872843424],
#                     [0.28350000381469725, 0.9924999872843424],
#                     [0.28350000381469725, 0.9924999872843424],
#                     [0.2934999942779541, 0.9924999872843424],
#                     [0.2934999942779541, 0.9924999872843424],
#                     [0.30249998569488523, 0.9924999872843424],
#                     [0.30249998569488523, 0.9924999872843424],
#                     [0.3115000009536743, 0.9924999872843424],
#                     [0.3115000009536743, 0.9924999872843424],
#                     [0.32149999141693114, 0.9924999872843424],
#                     [0.32149999141693114, 0.9924999872843424],
#                     [0.33249998092651367, 0.9924999872843424],
#                     [0.33249998092651367, 0.9924999872843424],
#                     [0.34249999523162844, 0.9924999872843424],
#                     [0.34249999523162844, 0.9924999872843424],
#                     [0.3514999866485596, 0.9924999872843424],
#                     [0.3514999866485596, 0.9924999872843424],
#                     [0.3634999990463257, 0.9924999872843424],
#                     [0.3634999990463257, 0.9924999872843424],
#                     [0.3724999904632568, 0.9924999872843424],
#                     [0.3724999904632568, 0.9924999872843424],
#                     [0.38249998092651366, 0.9924999872843424],
#                     [0.38249998092651366, 0.9924999872843424],
#                     [0.39149999618530273, 0.9924999872843424],
#                     [0.39149999618530273, 0.9924999872843424],
#                     [0.4005000114440918, 0.9924999872843424],
#                     [0.4005000114440918, 0.9924999872843424],
#                     [0.41050000190734864, 0.9924999872843424],
#                     [0.41050000190734864, 0.9924999872843424],
#                     [0.41949996948242185, 0.9924999872843424],
#                     [0.41949996948242185, 0.9924999872843424],
#                     [0.4284999847412109, 0.9924999872843424],
#                     [0.4284999847412109, 0.9924999872843424],
#                     [0.4375, 0.9924999872843424],
#                     [0.4375, 0.9924999872843424],
#                     [0.44749999046325684, 0.9924999872843424],
#                     [0.44749999046325684, 0.9924999872843424],
#                     [0.45850000381469724, 0.9924999872843424],
#                     [0.45850000381469724, 0.9924999872843424],
#                     [0.4684999942779541, 0.9924999872843424],
#                     [0.4684999942779541, 0.9924999872843424],
#                     [0.47750000953674315, 0.9924999872843424],
#                     [0.47750000953674315, 0.9924999872843424],
#                     [0.4864999771118164, 0.9924999872843424],
#                     [0.4864999771118164, 0.9924999872843424],
#                     [0.4954999923706055, 0.9924999872843424],
#                     [0.4954999923706055, 0.9924999872843424],
#                     [0.5045000076293945, 0.9924999872843424],
#                     [0.5045000076293945, 0.9924999872843424],
#                     [0.5134999752044678, 0.9924999872843424],
#                     [0.5134999752044678, 0.9924999872843424],
#                     [0.5204999923706055, 0.9924999872843424],
#                     [0.5204999923706055, 0.9924999872843424],
#                     [0.5295000076293945, 0.9924999872843424],
#                     [0.5295000076293945, 0.9924999872843424],
#                     [0.5384999752044678, 0.9924999872843424],
#                     [0.5384999752044678, 0.9924999872843424],
#                     [0.5484999656677246, 0.9924999872843424],
#                     [0.5484999656677246, 0.9924999872843424],
#                     [0.5574999809265136, 0.9924999872843424],
#                     [0.5574999809265136, 0.9924999872843424],
#                     [0.5664999961853028, 0.9924999872843424],
#                     [0.5664999961853028, 0.9924999872843424],
#                     [0.5754999637603759, 0.9924999872843424],
#                     [0.5754999637603759, 0.9924999872843424],
#                     [0.5855000019073486, 0.9924999872843424],
#                     [0.5855000019073486, 0.9924999872843424],
#                     [0.5964999675750733, 0.9924999872843424],
#                     [0.5964999675750733, 0.9924999872843424],
#                     [0.6054999828338623, 0.9924999872843424],
#                     [0.6054999828338623, 0.9924999872843424],
#                     [0.6154999732971191, 0.9924999872843424],
#                     [0.6154999732971191, 0.9924999872843424],
#                     [0.6244999885559082, 0.9924999872843424],
#                     [0.6244999885559082, 0.9924999872843424],
#                     [0.634499979019165, 0.9924999872843424],
#                     [0.634499979019165, 0.9924999872843424],
#                     [0.6454999923706055, 0.9924999872843424],
#                     [0.6454999923706055, 0.9924999872843424],
#                     [0.6545000076293945, 0.9924999872843424],
#                     [0.6545000076293945, 0.9924999872843424],
#                     [0.6644999980926514, 0.9924999872843424],
#                     [0.6644999980926514, 0.9924999872843424],
#                     [0.6734999656677246, 0.9924999872843424],
#                     [0.6734999656677246, 0.9924999872843424],
#                     [0.6824999809265136, 0.9924999872843424],
#                     [0.6824999809265136, 0.9924999872843424],
#                     [0.6944999694824219, 0.9924999872843424],
#                     [0.6944999694824219, 0.9924999872843424],
#                     [0.7034999847412109, 0.9924999872843424],
#                     [0.7034999847412109, 0.9924999872843424],
#                     [0.7134999752044677, 0.9924999872843424],
#                     [0.7134999752044677, 0.9924999872843424],
#                     [0.7244999885559082, 0.9924999872843424],
#                     [0.7244999885559082, 0.9924999872843424],
#                     [0.7344999790191651, 0.9924999872843424],
#                     [0.7344999790191651, 0.9924999872843424],
#                     [0.7434999942779541, 0.9924999872843424],
#                     [0.7434999942779541, 0.9924999872843424],
#                     [0.7524999618530274, 0.9924999872843424],
#                     [0.7524999618530274, 0.9924999872843424],
#                     [0.7614999771118164, 0.9924999872843424],
#                     [0.7614999771118164, 0.9924999872843424],
#                     [0.7724999904632568, 0.9924999872843424],
#                     [0.7724999904632568, 0.9924999872843424],
#                     [0.7835000038146973, 0.9924999872843424],
#                     [0.7835000038146973, 0.9924999872843424],
#                     [0.7934999942779541, 0.9924999872843424],
#                     [0.7934999942779541, 0.9924999872843424],
#                     [0.8024999618530273, 0.9924999872843424],
#                     [0.8024999618530273, 0.9924999872843424],
#                     [0.8125, 0.9924999872843424],
#                     [0.8125, 0.9924999872843424],
#                     [0.821500015258789, 0.9924999872843424],
#                     [0.821500015258789, 0.9924999872843424],
#                     [0.8335000038146972, 0.9924999872843424],
#                     [0.8335000038146972, 0.9924999872843424],
#                     [0.8425000190734864, 0.9924999872843424],
#                     [0.8425000190734864, 0.9924999872843424],
#                     [0.8514999389648438, 0.9924999872843424],
#                     [0.8514999389648438, 0.9924999872843424],
#                     [0.8614999771118164, 0.9924999872843424],
#                     [0.8614999771118164, 0.9924999872843424],
#                     [0.8704999923706055, 0.9924999872843424],
#                     [0.8704999923706055, 0.9924999872843424],
#                     [0.8824999809265137, 0.9924999872843424],
#                     [0.8824999809265137, 0.9924999872843424],
#                     [0.8914999961853027, 0.9924999872843424],
#                     [0.8914999961853027, 0.9924999872843424],
#                     [0.903499984741211, 0.9924999872843424],
#                     [0.903499984741211, 0.9924999872843424],
#                     [0.9144999504089355, 0.9924999872843424],
#                     [0.9144999504089355, 0.9924999872843424],
#                     [0.9244999885559082, 0.9924999872843424],
#                     [0.9244999885559082, 0.9924999872843424],
#                     [0.9364999771118164, 0.9924999872843424],
#                     [0.9364999771118164, 0.9924999872843424],
#                     [0.9454999923706054, 0.9924999872843424],
#                     [0.9454999923706054, 0.9924999872843424],
#                     [0.9545000076293946, 0.9924999872843424],
#                     [0.9545000076293946, 0.9924999872843424],
#                     [0.9635000228881836, 0.9924999872843424],
#                     [0.9635000228881836, 0.9924999872843424],
#                     [0.9734999656677246, 0.9924999872843424],
#                     [0.9734999656677246, 0.9924999872843424],
#                     [0.9854999542236328, 0.9924999872843424],
#                     [0.9854999542236328, 0.9924999872843424],
#                     [0.9944999694824219, 0.9924999872843424],
#                     [0.9944999694824219, 0.9924999872843424],
#                     [0.9994999885559082, 0.9924999872843424],
#                     [0.9994999885559082, 0.9924999872843424],
#                     [0.9994999885559082, 0.9924999872843424],
#                     [0.9994999885559082, 0.9944999694824219],
#                     [0.9994999885559082, 0.9944999694824219],
#                     [0.9994999885559082, 0.9944999694824219],
#                     [0.9965000152587891, 0.9944999694824219],
#                     [0.9965000152587891, 0.9924999872843424],
#                     [0.9994999885559082, 0.9924999872843424],
#                     [0.9994999885559082, 0.990500005086263],
#                     [0.9994999885559082, 0.990500005086263],
#                     [0.9994999885559082, 0.9924999872843424],
#                     [0.9965000152587891, 0.9924999872843424],
#                     [0.9965000152587891, 0.9924999872843424],
#                     [0.9854999542236328, 0.9924999872843424],
#                     [0.9854999542236328, 0.9944999694824219],
#                     [0.9784999847412109, 0.9944999694824219],
#                     [0.9784999847412109, 0.9944999694824219],
#                     [0.971500015258789, 0.9944999694824219],
#                     [0.971500015258789, 0.9924999872843424],
#                     [0.9614999771118165, 0.9924999872843424],
#                     [0.9614999771118165, 0.9924999872843424],
#                     [0.9494999885559082, 0.9924999872843424],
#                     [0.9494999885559082, 0.9924999872843424],
#                     [0.9385000228881836, 0.9924999872843424],
#                     [0.9385000228881836, 0.9924999872843424],
#                     [0.9295000076293946, 0.9924999872843424],
#                     [0.9295000076293946, 0.9924999872843424],
#                     [0.9175000190734863, 0.9924999872843424],
#                     [0.9175000190734863, 0.9924999872843424],
#                     [0.9074999809265136, 0.9924999872843424],
#                     [0.9074999809265136, 0.9924999872843424],
#                     [0.8965000152587891, 0.9924999872843424],
#                     [0.8965000152587891, 0.9924999872843424],
#                     [0.8845000267028809, 0.9924999872843424],
#                     [0.8845000267028809, 0.9924999872843424],
#                     [0.8755000114440918, 0.9924999872843424],
#                     [0.8755000114440918, 0.9924999872843424],
#                     [0.8654999732971191, 0.9924999872843424],
#                     [0.8654999732971191, 0.9924999872843424],
#                     [0.8545000076293945, 0.9924999872843424],
#                     [0.8545000076293945, 0.9924999872843424],
#                     [0.8444999694824219, 0.9924999872843424],
#                     [0.8444999694824219, 0.9924999872843424],
#                     [0.8354999542236328, 0.9924999872843424],
#                     [0.8354999542236328, 0.9924999872843424],
#                     [0.8264999389648438, 0.9924999872843424],
#                     [0.8264999389648438, 0.9924999872843424],
#                     [0.8144999504089355, 0.9924999872843424],
#                     [0.8144999504089355, 0.9924999872843424],
#                     [0.8054999351501465, 0.9924999872843424],
#                     [0.8054999351501465, 0.9924999872843424],
#                     [0.7954999923706054, 0.9924999872843424],
#                     [0.7954999923706054, 0.9924999872843424],
#                     [0.7864999771118164, 0.9924999872843424],
#                     [0.7864999771118164, 0.9924999872843424],
#                     [0.7744999885559082, 0.9924999872843424],
#                     [0.7744999885559082, 0.9924999872843424],
#                     [0.7634999752044678, 0.9924999872843424],
#                     [0.7634999752044678, 0.9924999872843424],
#                     [0.7544999599456788, 0.9924999872843424],
#                     [0.7544999599456788, 0.9924999872843424],
#                     [0.7454999923706055, 0.9924999872843424],
#                     [0.7454999923706055, 0.9924999872843424],
#                     [0.7364999771118164, 0.9924999872843424],
#                     [0.7364999771118164, 0.9924999872843424],
#                     [0.725499963760376, 0.9924999872843424],
#                     [0.725499963760376, 0.9924999872843424],
#                     [0.7154999732971191, 0.9924999872843424],
#                     [0.7154999732971191, 0.9924999872843424],
#                     [0.7014999866485596, 0.9924999872843424],
#                     [0.7014999866485596, 0.9924999872843424],
#                     [0.6894999980926514, 0.9924999872843424],
#                     [0.6894999980926514, 0.9924999872843424],
#                     [0.678499984741211, 0.9924999872843424],
#                     [0.678499984741211, 0.9924999872843424],
#                     [0.6684999942779541, 0.9924999872843424],
#                     [0.6684999942779541, 0.9924999872843424],
#                     [0.6574999809265136, 0.9924999872843424],
#                     [0.6574999809265136, 0.9924999872843424],
#                     [0.6434999942779541, 0.9924999872843424],
#                     [0.6434999942779541, 0.9924999872843424],
#                     [0.6315000057220459, 0.9924999872843424],
#                     [0.6315000057220459, 0.9924999872843424],
#                     [0.6204999923706055, 0.9924999872843424],
#                     [0.6204999923706055, 0.9924999872843424],
#                     [0.6105000019073487, 0.9924999872843424],
#                     [0.6105000019073487, 0.9924999872843424],
#                     [0.6014999866485595, 0.9924999872843424],
#                     [0.6014999866485595, 0.9924999872843424],
#                     [0.5924999713897705, 0.9924999872843424],
#                     [0.5924999713897705, 0.9924999872843424],
#                     [0.5824999809265137, 0.9924999872843424],
#                     [0.5824999809265137, 0.9924999872843424],
#                     [0.5714999675750733, 0.9924999872843424],
#                     [0.5714999675750733, 0.9924999872843424],
#                     [0.559499979019165, 0.9924999872843424],
#                     [0.559499979019165, 0.9924999872843424],
#                     [0.5505000114440918, 0.9924999872843424],
#                     [0.5505000114440918, 0.9924999872843424],
#                     [0.5414999961853028, 0.9924999872843424],
#                     [0.5414999961853028, 0.9924999872843424],
#                     [0.5315000057220459, 0.9924999872843424],
#                     [0.5315000057220459, 0.9924999872843424],
#                     [0.5224999904632568, 0.9924999872843424],
#                     [0.5224999904632568, 0.9924999872843424],
#                     [0.5114999771118164, 0.9924999872843424],
#                     [0.5114999771118164, 0.9924999872843424],
#                     [0.5025000095367431, 0.9924999872843424],
#                     [0.5025000095367431, 0.9924999872843424],
#                     [0.4934999942779541, 0.9924999872843424],
#                     [0.4934999942779541, 0.9924999872843424],
#                     [0.48449997901916503, 0.9924999872843424],
#                     [0.48449997901916503, 0.9924999872843424],
#                     [0.4744999885559082, 0.9924999872843424],
#                     [0.4744999885559082, 0.9924999872843424],
#                     [0.4634999752044678, 0.9924999872843424],
#                     [0.4634999752044678, 0.9924999872843424],
#                     [0.45149998664855956, 0.9924999872843424],
#                     [0.45149998664855956, 0.9924999872843424],
#                     [0.4424999713897705, 0.9924999872843424],
#                     [0.4424999713897705, 0.9924999872843424],
#                     [0.4304999828338623, 0.9924999872843424],
#                     [0.4304999828338623, 0.9924999872843424],
#                     [0.4184999942779541, 0.9924999872843424],
#                     [0.4184999942779541, 0.9924999872843424],
#                     [0.4074999809265137, 0.9924999872843424],
#                     [0.4074999809265137, 0.9924999872843424],
#                     [0.39549999237060546, 0.9924999872843424],
#                     [0.39549999237060546, 0.9924999872843424],
#                     [0.3865000009536743, 0.9924999872843424],
#                     [0.3865000009536743, 0.9924999872843424],
#                     [0.3744999885559082, 0.9924999872843424],
#                     [0.3744999885559082, 0.9924999872843424],
#                     [0.3654999971389771, 0.9924999872843424],
#                     [0.3654999971389771, 0.9924999872843424],
#                     [0.3534999847412109, 0.9924999872843424],
#                     [0.3534999847412109, 0.9924999872843424],
#                     [0.3444999933242798, 0.9924999872843424],
#                     [0.3444999933242798, 0.9924999872843424],
#                     [0.33550000190734863, 0.9924999872843424],
#                     [0.33550000190734863, 0.9924999872843424],
#                     [0.32549998760223386, 0.9924999872843424],
#                     [0.32549998760223386, 0.9924999872843424],
#                     [0.3144999980926514, 0.9924999872843424],
#                     [0.3144999980926514, 0.9924999872843424],
#                     [0.3044999837875366, 0.9924999872843424],
#                     [0.3044999837875366, 0.9924999872843424],
#                     [0.2954999923706055, 0.9924999872843424],
#                     [0.2954999923706055, 0.9924999872843424],
#                     [0.281499981880188, 0.9924999872843424],
#                     [0.281499981880188, 0.9924999872843424],
#                     [0.27049999237060546, 0.9924999872843424],
#                     [0.27049999237060546, 0.9924999872843424],
#                     [0.2605000019073486, 0.9924999872843424],
#                     [0.2605000019073486, 0.9924999872843424],
#                     [0.24949998855590821, 0.9924999872843424],
#                     [0.24949998855590821, 0.9924999872843424],
#                     [0.23949999809265138, 0.9924999872843424],
#                     [0.23949999809265138, 0.9924999872843424],
#                     [0.2305000066757202, 0.9924999872843424],
#                     [0.2305000066757202, 0.9924999872843424],
#                     [0.22149999141693116, 0.9924999872843424],
#                     [0.22149999141693116, 0.9924999872843424],
#                     [0.21050000190734863, 0.9924999872843424],
#                     [0.21050000190734863, 0.9924999872843424],
#                     [0.19850000143051147, 0.9924999872843424],
#                     [0.19850000143051147, 0.9924999872843424],
#                     [0.1865000009536743, 0.9924999872843424],
#                     [0.1865000009536743, 0.9924999872843424],
#                     [0.17549999952316284, 0.9924999872843424],
#                     [0.17549999952316284, 0.9924999872843424],
#                     [0.16549999713897706, 0.9924999872843424],
#                     [0.16549999713897706, 0.9924999872843424],
#                     [0.15649999380111695, 0.9924999872843424],
#                     [0.15649999380111695, 0.9924999872843424],
#                     [0.14549999237060546, 0.9924999872843424],
#                     [0.14549999237060546, 0.9924999872843424],
#                     [0.13550000190734862, 0.9924999872843424],
#                     [0.13550000190734862, 0.9924999872843424],
#                     [0.12649999856948851, 0.9924999872843424],
#                     [0.12649999856948851, 0.9924999872843424],
#                     [0.11449999809265136, 0.9924999872843424],
#                     [0.11449999809265136, 0.9924999872843424],
#                     [0.10549999475479126, 0.9924999872843424],
#                     [0.10549999475479126, 0.9924999872843424],
#                     [0.09449999928474426, 0.9924999872843424],
#                     [0.09449999928474426, 0.9924999872843424],
#                     [0.08449999690055847, 0.9924999872843424],
#                     [0.08449999690055847, 0.9924999872843424],
#                     [0.073499995470047, 0.9924999872843424],
#                     [0.073499995470047, 0.9924999872843424],
#                     [0.06150000095367432, 0.9924999872843424],
#                     [0.06150000095367432, 0.9924999872843424],
#                     [0.04749999940395355, 0.9924999872843424],
#                     [0.04749999940395355, 0.9924999872843424],
#                     [0.033499997854232785, 0.9924999872843424],
#                     [0.033499997854232785, 0.9924999872843424],
#                     [0.02449999898672104, 0.9924999872843424],
#                     [0.02449999898672104, 0.9924999872843424],
#                     [0.0125, 0.9924999872843424],
#                     [0.0125, 0.9924999872843424],
#                     [0.0004999999888241291, 0.9924999872843424],
#                     [0.0004999999888241291, 0.990500005086263],
#                     [0.0004999999888241291, 0.990500005086263],
#                     [0.0004999999888241291, 0.9924999872843424],
#                     [0.002499999850988388, 0.9924999872843424],
#                     [0.002499999850988388, 0.9924999872843424],
#                     [0.01550000011920929, 0.9924999872843424],
#                     [0.01550000011920929, 0.9944999694824219],
#                     [0.029499998688697814, 0.9944999694824219],
#                     [0.029499998688697814, 0.9924999872843424],
#                     [0.04050000011920929, 0.9924999872843424],
#                     [0.04050000011920929, 0.9924999872843424],
#                     [0.054500001668930056, 0.9924999872843424],
#                     [0.054500001668930056, 0.9924999872843424],
#                     [0.06850000023841858, 0.9924999872843424],
#                     [0.06850000023841858, 0.9924999872843424],
#                     [0.08050000071525573, 0.9924999872843424],
#                     [0.08050000071525573, 0.9924999872843424],
#                     [0.09149999618530273, 0.9924999872843424],
#                     [0.09149999618530273, 0.9924999872843424],
#                     [0.10149999856948852, 0.9924999872843424],
#                     [0.10149999856948852, 0.9924999872843424],
#                     [0.1125, 0.9924999872843424],
#                     [0.1125, 0.9924999872843424],
#                     [0.12149999141693116, 0.9924999872843424],
#                     [0.12149999141693116, 0.9924999872843424],
#                     [0.13349999189376832, 0.9924999872843424],
#                     [0.13349999189376832, 0.9924999872843424],
#                     [0.14249999523162843, 0.9924999872843424],
#                     [0.14249999523162843, 0.9924999872843424],
#                     [0.15149999856948854, 0.9924999872843424],
#                     [0.15149999856948854, 0.9924999872843424],
#                     [0.1615000009536743, 0.9924999872843424],
#                     [0.1615000009536743, 0.9924999872843424],
#                     [0.17249999046325684, 0.9924999872843424],
#                     [0.17249999046325684, 0.9924999872843424],
#                     [0.18249999284744262, 0.9924999872843424],
#                     [0.18249999284744262, 0.9924999872843424],
#                     [0.1934999942779541, 0.9924999872843424],
#                     [0.1934999942779541, 0.9924999872843424],
#                     [0.20550000667572021, 0.9924999872843424],
#                     [0.20550000667572021, 0.9924999872843424],
#                     [0.21449999809265136, 0.9924999872843424],
#                     [0.21449999809265136, 0.9924999872843424],
#                     [0.2244999885559082, 0.9924999872843424],
#                     [0.2244999885559082, 0.9924999872843424],
#                     [0.23550000190734863, 0.9924999872843424],
#                     [0.23550000190734863, 0.9924999872843424],
#                     [0.2444999933242798, 0.9924999872843424],
#                     [0.2444999933242798, 0.9924999872843424],
#                     [0.25349998474121094, 0.9924999872843424],
#                     [0.25349998474121094, 0.9924999872843424],
#                     [0.2634999990463257, 0.9924999872843424],
#                     [0.2634999990463257, 0.9924999872843424],
#                     [0.27249999046325685, 0.9924999872843424],
#                     [0.27249999046325685, 0.9924999872843424],
#                     [0.28450000286102295, 0.9924999872843424],
#                     [0.28450000286102295, 0.9924999872843424],
#                     [0.2964999914169312, 0.9924999872843424],
#                     [0.2964999914169312, 0.9924999872843424],
#                     [0.3075000047683716, 0.9924999872843424],
#                     [0.3075000047683716, 0.9924999872843424],
#                     [0.3184999942779541, 0.9924999872843424],
#                     [0.3184999942779541, 0.9924999872843424],
#                     [0.32849998474121095, 0.9924999872843424],
#                     [0.32849998474121095, 0.9924999872843424],
#                     [0.34049999713897705, 0.9924999872843424],
#                     [0.34049999713897705, 0.9924999872843424],
#                     [0.3494999885559082, 0.9924999872843424],
#                     [0.3494999885559082, 0.9924999872843424],
#                     [0.35850000381469727, 0.9924999872843424],
#                     [0.35850000381469727, 0.9924999872843424],
#                     [0.3674999952316284, 0.9924999872843424],
#                     [0.3674999952316284, 0.9924999872843424],
#                     [0.37749998569488524, 0.9924999872843424],
#                     [0.37749998569488524, 0.9924999872843424],
#                     [0.38949999809265134, 0.9924999872843424],
#                     [0.38949999809265134, 0.9924999872843424],
#                     [0.39849998950958254, 0.9924999872843424],
#                     [0.39849998950958254, 0.9924999872843424],
#                     [0.409499979019165, 0.9924999872843424],
#                     [0.409499979019165, 0.9924999872843424],
#                     [0.42149996757507324, 0.9924999872843424],
#                     [0.42149996757507324, 0.9924999872843424],
#                     [0.43249998092651365, 0.9924999872843424],
#                     [0.43249998092651365, 0.9924999872843424],
#                     [0.4444999694824219, 0.9924999872843424],
#                     [0.4444999694824219, 0.9924999872843424],
#                     [0.45349998474121095, 0.9924999872843424],
#                     [0.45349998474121095, 0.9924999872843424],
#                     [0.4654999732971191, 0.9924999872843424],
#                     [0.4654999732971191, 0.9924999872843424],
#                     [0.47249999046325686, 0.9924999872843424],
#                     [0.47249999046325686, 0.9924999872843424],
#                     [0.46050000190734863, 0.9924999872843424],
#                     [0.46050000190734863, 0.9924999872843424],
#                     [0.4494999885559082, 0.9924999872843424],
#                     [0.4494999885559082, 0.9924999872843424],
#                     [0.4355000019073486, 0.9924999872843424],
#                     [0.4355000019073486, 0.9924999872843424],
#                     [0.42350001335144044, 0.9924999872843424],
#                     [0.42350001335144044, 0.9924999872843424],
#                     [0.41449999809265137, 0.9924999872843424],
#                     [0.41449999809265137, 0.9924999872843424],
#                     [0.40250000953674314, 0.9924999872843424],
#                     [0.40250000953674314, 0.9924999872843424],
#                     [0.39049999713897704, 0.9924999872843424],
#                     [0.39049999713897704, 0.9924999872843424],
#                     [0.37949998378753663, 0.9924999872843424],
#                     [0.37949998378753663, 0.9924999872843424],
#                     [0.3654999971389771, 0.9924999872843424],
#                     [0.3654999971389771, 0.990500005086263],
#                     [0.3534999847412109, 0.990500005086263],
#                     [0.3534999847412109, 0.9924999872843424],
#                     [0.34249999523162844, 0.9924999872843424],
#                     [0.34249999523162844, 0.990500005086263],
#                     [0.3304999828338623, 0.990500005086263],
#                     [0.3304999828338623, 0.9924999872843424],
#                     [0.3184999942779541, 0.9924999872843424],
#                     [0.3184999942779541, 0.990500005086263],
#                     [0.3075000047683716, 0.990500005086263],
#                     [0.3075000047683716, 0.9924999872843424],
#                     [0.2934999942779541, 0.9924999872843424],
#                     [0.2934999942779541, 0.990500005086263],
#                     [0.281499981880188, 0.990500005086263],
#                     [0.281499981880188, 0.9924999872843424],
#                     [0.26949999332427976, 0.9924999872843424],
#                     [0.26949999332427976, 0.9924999872843424],
#                     [0.2585000038146973, 0.9924999872843424],
#                     [0.2585000038146973, 0.9924999872843424],
#                     [0.24749999046325682, 0.9924999872843424],
#                     [0.24749999046325682, 0.9924999872843424],
#                     [0.23350000381469727, 0.9924999872843424],
#                     [0.23350000381469727, 0.9924999872843424],
#                     [0.22349998950958253, 0.9924999872843424],
#                     [0.22349998950958253, 0.9924999872843424],
#                     [0.2125, 0.9924999872843424],
#                     [0.2125, 0.9924999872843424],
#                     [0.20249998569488525, 0.9924999872843424],
#                     [0.20249998569488525, 0.9924999872843424],
#                     [0.1884999990463257, 0.9924999872843424],
#                     [0.1884999990463257, 0.9924999872843424],
#                     [0.1794999957084656, 0.9924999872843424],
#                     [0.1794999957084656, 0.9924999872843424],
#                     [0.1684999942779541, 0.9924999872843424],
#                     [0.1684999942779541, 0.9924999872843424],
#                     [0.15849999189376832, 0.9924999872843424],
#                     [0.15849999189376832, 0.9924999872843424],
#                     [0.14950000047683715, 0.9924999872843424],
#                     [0.14950000047683715, 0.9924999872843424],
#                     [0.14049999713897704, 0.9924999872843424],
#                     [0.14049999713897704, 0.9924999872843424],
#                     [0.13049999475479127, 0.9924999872843424],
#                     [0.13049999475479127, 0.9924999872843424],
#                     [0.11749999523162842, 0.9924999872843424],
#                     [0.11749999523162842, 0.9924999872843424],
#                     [0.10849999189376831, 0.9924999872843424],
#                     [0.10849999189376831, 0.9924999872843424],
#                     [0.098499995470047, 0.9924999872843424],
#                     [0.098499995470047, 0.9924999872843424],
#                     [0.0875, 0.9924999872843424],
#                     [0.0875, 0.9924999872843424],
#                     [0.0774999976158142, 0.9924999872843424],
#                     [0.0774999976158142, 0.9924999872843424],
#                     [0.06449999809265136, 0.9924999872843424],
#                     [0.06449999809265136, 0.9924999872843424],
#                     [0.05249999761581421, 0.9924999872843424],
#                     [0.05249999761581421, 0.990500005086263],
#                     [0.04050000011920929, 0.990500005086263],
#                     [0.04050000011920929, 0.9924999872843424],
#                     [0.031499999761581424, 0.9924999872843424],
#                     [0.031499999761581424, 0.9924999872843424],
#                     [0.019499999284744263, 0.9924999872843424],
#                     [0.019499999284744263, 0.9924999872843424],
#                     [0.008500000089406967, 0.9924999872843424],
#                     [0.008500000089406967, 0.9924999872843424],
#                     [0.0004999999888241291, 0.9924999872843424],
#                     [0.0004999999888241291, 0.9854999542236328],
#                     [0.0004999999888241291, 0.9854999542236328],
#                     [0.0004999999888241291, 0.9854999542236328],
#                     [0.0014999999664723873, 0.9854999542236328],
#                     [0.0014999999664723873, 0.9854999542236328],
#                     [0.0004999999888241291, 0.9854999542236328],
#                     [0.0004999999888241291, 0.9875],
#                     [0.0004999999888241291, 0.9875],
#                     [0.0004999999888241291, 0.9875],
#                     [0.0014999999664723873, 0.9875],
#                     [0.0014999999664723873, 0.9875],
#                     [0.0004999999888241291, 0.9875],
#                     [0.0004999999888241291, 0.9924999872843424],
#                     [0.0064999997615814206, 0.9924999872843424],
#                     [0.0064999997615814206, 0.9924999872843424],
#                     [0.017499999701976778, 0.9924999872843424],
#                     [0.017499999701976778, 0.9924999872843424],
#                     [0.033499997854232785, 0.9924999872843424],
#                     [0.033499997854232785, 0.990500005086263],
#                     [0.04749999940395355, 0.990500005086263],
#                     [0.04749999940395355, 0.9924999872843424],
#                     [0.06150000095367432, 0.9924999872843424],
#                     [0.06150000095367432, 0.990500005086263],
#                     [0.073499995470047, 0.990500005086263],
#                     [0.073499995470047, 0.9924999872843424],
#                     [0.08449999690055847, 0.9924999872843424],
#                     [0.08449999690055847, 0.990500005086263],
#                     [0.09649999737739563, 0.990500005086263],
#                     [0.09649999737739563, 0.9924999872843424],
#                     [0.10849999189376831, 0.9924999872843424],
#                     [0.10849999189376831, 0.990500005086263],
#                     [0.11949999332427978, 0.990500005086263],
#                     [0.11949999332427978, 0.9924999872843424],
#                     [0.13149999380111693, 0.9924999872843424],
#                     [0.13149999380111693, 0.9924999872843424],
#                     [0.14249999523162843, 0.9924999872843424],
#                     [0.14249999523162843, 0.990500005086263],
#                     [0.15149999856948854, 0.990500005086263],
#                     [0.15149999856948854, 0.9924999872843424],
#                     [0.16349999904632567, 0.9924999872843424],
#                     [0.16349999904632567, 0.990500005086263],
#                     [0.17549999952316284, 0.990500005086263],
#                     [0.17549999952316284, 0.9924999872843424],
#                     [0.184499990940094, 0.9924999872843424],
#                     [0.184499990940094, 0.990500005086263],
#                     [0.1934999942779541, 0.990500005086263],
#                     [0.1934999942779541, 0.9924999872843424],
#                     [0.20349998474121095, 0.9924999872843424],
#                     [0.20349998474121095, 0.9924999872843424],
#                     [0.2174999952316284, 0.9924999872843424],
#                     [0.2174999952316284, 0.9924999872843424],
#                     [0.22649998664855958, 0.9924999872843424],
#                     [0.22649998664855958, 0.9924999872843424],
#                     [0.23949999809265138, 0.9924999872843424],
#                     [0.23949999809265138, 0.990500005086263],
#                     [0.24949998855590821, 0.990500005086263],
#                     [0.24949998855590821, 0.9924999872843424],
#                     [0.2605000019073486, 0.9924999872843424],
#                     [0.2605000019073486, 0.990500005086263],
#                     [0.2744999885559082, 0.990500005086263],
#                     [0.2744999885559082, 0.9924999872843424],
#                     [0.28650000095367434, 0.9924999872843424],
#                     [0.28650000095367434, 0.9924999872843424],
#                     [0.2984999895095825, 0.9924999872843424],
#                     [0.2984999895095825, 0.9924999872843424],
#                     [0.30950000286102297, 0.9924999872843424],
#                     [0.30950000286102297, 0.9924999872843424],
#                     [0.32149999141693114, 0.9924999872843424],
#                     [0.32149999141693114, 0.990500005086263],
#                     [0.33350000381469724, 0.990500005086263],
#                     [0.33350000381469724, 0.9924999872843424],
#                     [0.3444999933242798, 0.9924999872843424],
#                     [0.3444999933242798, 0.990500005086263],
#                     [0.3544999837875366, 0.990500005086263],
#                     [0.3544999837875366, 0.9924999872843424],
#                     [0.3634999990463257, 0.9924999872843424],
#                     [0.3634999990463257, 0.990500005086263],
#                     [0.3724999904632568, 0.990500005086263],
#                     [0.3724999904632568, 0.9924999872843424],
#                     [0.3845000028610229, 0.9924999872843424],
#                     [0.3845000028610229, 0.9924999872843424],
#                     [0.3934999942779541, 0.9924999872843424],
#                     [0.3934999942779541, 0.9924999872843424],
#                     [0.40250000953674314, 0.9924999872843424],
#                     [0.40250000953674314, 0.990500005086263],
#                     [0.41449999809265137, 0.990500005086263],
#                     [0.41449999809265137, 0.9924999872843424],
#                     [0.4255000114440918, 0.9924999872843424],
#                     [0.4255000114440918, 0.9924999872843424],
#                     [0.4375, 0.9924999872843424],
#                     [0.4375, 0.990500005086263],
#                     [0.4494999885559082, 0.990500005086263],
#                     [0.4494999885559082, 0.9924999872843424],
#                     [0.4565000057220459, 0.9924999872843424],
#                     [0.4565000057220459, 0.9924999872843424],
#                     [0.4674999713897705, 0.9924999872843424],
#                     [0.4674999713897705, 0.9924999872843424],
#                     [0.47950000762939454, 0.9924999872843424],
#                     [0.47950000762939454, 0.9924999872843424],
#                     [0.48849997520446775, 0.9924999872843424],
#                     [0.48849997520446775, 0.9924999872843424],
#                     [0.4984999656677246, 0.9924999872843424],
#                     [0.4984999656677246, 0.9924999872843424],
#                     [0.509499979019165, 0.9924999872843424],
#                     [0.509499979019165, 0.9924999872843424],
#                     [0.5184999942779541, 0.9924999872843424],
#                     [0.5184999942779541, 0.9924999872843424],
#                     [0.5275000095367431, 0.9924999872843424],
#                     [0.5275000095367431, 0.9924999872843424],
#                     [0.5364999771118164, 0.9924999872843424],
#                     [0.5364999771118164, 0.9924999872843424],
#                     [0.5454999923706054, 0.9924999872843424],
#                     [0.5454999923706054, 0.9924999872843424],
#                     [0.5525000095367432, 0.9924999872843424],
#                     [0.5525000095367432, 0.9924999872843424],
#                     [0.5614999771118164, 0.9924999872843424],
#                     [0.5614999771118164, 0.9924999872843424],
#                     [0.5734999656677247, 0.9924999872843424],
#                     [0.5734999656677247, 0.9924999872843424],
#                     [0.5804999828338623, 0.9924999872843424],
#                     [0.5804999828338623, 0.9924999872843424],
#                     [0.5894999980926514, 0.9924999872843424],
#                     [0.5894999980926514, 0.9924999872843424],
#                     [0.5994999885559082, 0.9924999872843424],
#                     [0.5994999885559082, 0.9924999872843424],
#                     [0.6085000038146973, 0.9924999872843424],
#                     [0.6085000038146973, 0.9924999872843424],
#                     [0.6174999713897705, 0.9924999872843424],
#                     [0.6174999713897705, 0.9924999872843424],
#                     [0.6275000095367431, 0.9924999872843424],
#                     [0.6275000095367431, 0.9924999872843424],
#                     [0.6384999752044678, 0.9924999872843424],
#                     [0.6384999752044678, 0.9924999872843424],
#                     [0.6484999656677246, 0.9924999872843424],
#                     [0.6484999656677246, 0.9924999872843424],
#                     [0.659499979019165, 0.9924999872843424],
#                     [0.659499979019165, 0.9924999872843424],
#                     [0.6694999694824219, 0.9924999872843424],
#                     [0.6694999694824219, 0.9924999872843424],
#                     [0.6804999828338623, 0.9924999872843424],
#                     [0.6804999828338623, 0.9924999872843424],
#                     [0.6924999713897705, 0.9924999872843424],
#                     [0.6924999713897705, 0.9924999872843424],
#                     [0.6994999885559082, 0.9924999872843424],
#                     [0.6994999885559082, 0.9924999872843424],
#                     [0.7105000019073486, 0.9924999872843424],
#                     [0.7105000019073486, 0.9924999872843424],
#                     [0.7204999923706055, 0.9924999872843424],
#                     [0.7204999923706055, 0.9924999872843424],
#                     [0.7294999599456787, 0.9924999872843424],
#                     [0.7294999599456787, 0.9924999872843424],
#                     [0.7414999961853027, 0.9924999872843424],
#                     [0.7414999961853027, 0.9924999872843424],
#                     [0.750499963760376, 0.9924999872843424],
#                     [0.750499963760376, 0.9924999872843424],
#                     [0.759499979019165, 0.9924999872843424],
#                     [0.759499979019165, 0.9924999872843424],
#                     [0.7704999923706055, 0.9924999872843424],
#                     [0.7704999923706055, 0.9924999872843424],
#                     [0.49049997329711914, 0.9924999872843424],
#                 ],
#             ],
#             'confidence': None,
#             'index': None,
#             'closed': True,
#             'filled': True,
#         }>,
#     ],
# }>

# %%
await florence2_referring_segmentation(
    smol_ds,
    model_path=MODEL_PATH,
    expression="people in the background",
    output_field="open_expression_segmentations",
    delegate=True
)

# %%
smol_ds.first()['open_expression_segmentations']
# Out:
# <Polylines: {
#     'polylines': [
#         <Polyline: {
#             'id': '67e1cdb6b161a758312e0e7d',
#             'attributes': {},
#             'tags': [],
#             'label': 'object_1',
#             'points': [
#                 [
#                     [0.5804999828338623, 0.25849998792012535],
#                     [0.5914999961853027, 0.25849998792012535],
#                     [0.5914999961853027, 0.24249998728434244],
#                     [0.6054999828338623, 0.24249998728434244],
#                     [0.6054999828338623, 0.23849999109903972],
#                     [0.6224999904632569, 0.23849999109903972],
#                     [0.6224999904632569, 0.23849999109903972],
#                     [0.6375, 0.23849999109903972],
#                     [0.6375, 0.24549999237060546],
#                     [0.6524999618530274, 0.24549999237060546],
#                     [0.6524999618530274, 0.2535000006357829],
#                     [0.6674999713897705, 0.2535000006357829],
#                     [0.6674999713897705, 0.25849998792012535],
#                     [0.6815000057220459, 0.25849998792012535],
#                     [0.6815000057220459, 0.26449999809265134],
#                     [0.6954999923706054, 0.26449999809265134],
#                     [0.6954999923706054, 0.27049999237060546],
#                     [0.7065000057220459, 0.27049999237060546],
#                     [0.7065000057220459, 0.27849998474121096],
#                     [0.7154999732971191, 0.27849998474121096],
#                     [0.7154999732971191, 0.29149999618530276],
#                     [0.7214999675750733, 0.29149999618530276],
#                     [0.7214999675750733, 0.30649998982747395],
#                     [0.725499963760376, 0.30649998982747395],
#                     [0.725499963760376, 0.31950000127156575],
#                     [0.7284999847412109, 0.31950000127156575],
#                     [0.7284999847412109, 0.3304999987284342],
#                     [0.7294999599456787, 0.3304999987284342],
#                     [0.7294999599456787, 0.34149999618530275],
#                     [0.7294999599456787, 0.34149999618530275],
#                     [0.7294999599456787, 0.3524999936421712],
#                     [0.7284999847412109, 0.3524999936421712],
#                     [0.7284999847412109, 0.3634999910990397],
#                     [0.7264999866485595, 0.3634999910990397],
#                     [0.7264999866485595, 0.3744999885559082],
#                     [0.7234999656677246, 0.3744999885559082],
#                     [0.7234999656677246, 0.3835000038146973],
#                     [0.7194999694824219, 0.3835000038146973],
#                     [0.7194999694824219, 0.3884999910990397],
#                     [0.7134999752044677, 0.3884999910990397],
#                     [0.7134999752044677, 0.3884999910990397],
#                     [0.7065000057220459, 0.3884999910990397],
#                     [0.7065000057220459, 0.3884999910990397],
#                     [0.7014999866485596, 0.3884999910990397],
#                     [0.7014999866485596, 0.3854999860127767],
#                     [0.6994999885559082, 0.3854999860127767],
#                     [0.6994999885559082, 0.37849998474121094],
#                     [0.6994999885559082, 0.37849998474121094],
#                     [0.6994999885559082, 0.36849997838338217],
#                     [0.6994999885559082, 0.36849997838338217],
#                     [0.6994999885559082, 0.3574999809265137],
#                     [0.6994999885559082, 0.3574999809265137],
#                     [0.6994999885559082, 0.3484999974568685],
#                     [0.6994999885559082, 0.3484999974568685],
#                     [0.6994999885559082, 0.34149999618530275],
#                     [0.6994999885559082, 0.34149999618530275],
#                     [0.6994999885559082, 0.334499994913737],
#                     [0.6974999904632568, 0.334499994913737],
#                     [0.6974999904632568, 0.3295000076293945],
#                     [0.6924999713897705, 0.3295000076293945],
#                     [0.6924999713897705, 0.3295000076293945],
#                     [0.6864999771118164, 0.3295000076293945],
#                     [0.6864999771118164, 0.3295000076293945],
#                     [0.6835000038146972, 0.3295000076293945],
#                     [0.6835000038146972, 0.3295000076293945],
#                     [0.6835000038146972, 0.3295000076293945],
#                     [0.6835000038146972, 0.34149999618530275],
#                     [0.6835000038146972, 0.34149999618530275],
#                     [0.6835000038146972, 0.3524999936421712],
#                     [0.6835000038146972, 0.3524999936421712],
#                     [0.6835000038146972, 0.36449998219807944],
#                     [0.6835000038146972, 0.36449998219807944],
#                     [0.6835000038146972, 0.3765000025431315],
#                     [0.6835000038146972, 0.3765000025431315],
#                     [0.6835000038146972, 0.3854999860127767],
#                     [0.6835000038146972, 0.3854999860127767],
#                     [0.6835000038146972, 0.39249998728434243],
#                     [0.678499984741211, 0.39249998728434243],
#                     [0.678499984741211, 0.39249998728434243],
#                     [0.6724999904632568, 0.39249998728434243],
#                     [0.6724999904632568, 0.39249998728434243],
#                     [0.6674999713897705, 0.39249998728434243],
#                     [0.6674999713897705, 0.39249998728434243],
#                     [0.6605000019073486, 0.39249998728434243],
#                     [0.6605000019073486, 0.39249998728434243],
#                     [0.6554999828338623, 0.39249998728434243],
#                     [0.6554999828338623, 0.39249998728434243],
#                     [0.6554999828338623, 0.39249998728434243],
#                     [0.6554999828338623, 0.3854999860127767],
#                     [0.6554999828338623, 0.3854999860127767],
#                     [0.6554999828338623, 0.3765000025431315],
#                     [0.6554999828338623, 0.3765000025431315],
#                     [0.6554999828338623, 0.3664999961853027],
#                     [0.6554999828338623, 0.3664999961853027],
#                     [0.6554999828338623, 0.3574999809265137],
#                     [0.6554999828338623, 0.3574999809265137],
#                     [0.6554999828338623, 0.3484999974568685],
#                     [0.6554999828338623, 0.3484999974568685],
#                     [0.6554999828338623, 0.34149999618530275],
#                     [0.6554999828338623, 0.34149999618530275],
#                     [0.6554999828338623, 0.334499994913737],
#                     [0.6554999828338623, 0.334499994913737],
#                     [0.6554999828338623, 0.32749999364217125],
#                     [0.6484999656677246, 0.32749999364217125],
#                     [0.6484999656677246, 0.32749999364217125],
#                     [0.6394999980926513, 0.32749999364217125],
#                     [0.6394999980926513, 0.32749999364217125],
#                     [0.6324999809265137, 0.32749999364217125],
#                     [0.6324999809265137, 0.32749999364217125],
#                     [0.625499963760376, 0.32749999364217125],
#                     [0.625499963760376, 0.32749999364217125],
#                     [0.6184999942779541, 0.32749999364217125],
#                     [0.6184999942779541, 0.32749999364217125],
#                     [0.6134999752044678, 0.32749999364217125],
#                     [0.6134999752044678, 0.32749999364217125],
#                     [0.6085000038146973, 0.32749999364217125],
#                     [0.6085000038146973, 0.32749999364217125],
#                     [0.6054999828338623, 0.32749999364217125],
#                     [0.6054999828338623, 0.32749999364217125],
#                     [0.6054999828338623, 0.32749999364217125],
#                     [0.6054999828338623, 0.334499994913737],
#                     [0.6054999828338623, 0.334499994913737],
#                     [0.6054999828338623, 0.34149999618530275],
#                     [0.6054999828338623, 0.34149999618530275],
#                     [0.6054999828338623, 0.3504999796549479],
#                     [0.6054999828338623, 0.3504999796549479],
#                     [0.6054999828338623, 0.35949999491373696],
#                     [0.6054999828338623, 0.35949999491373696],
#                     [0.6054999828338623, 0.3714999834696452],
#                     [0.6054999828338623, 0.3714999834696452],
#                     [0.6054999828338623, 0.37849998474121094],
#                     [0.600499963760376, 0.37849998474121094],
#                     [0.600499963760376, 0.37849998474121094],
#                     [0.5944999694824219, 0.37849998474121094],
#                     [0.5944999694824219, 0.37849998474121094],
#                     [0.5894999980926514, 0.37849998474121094],
#                     [0.5894999980926514, 0.37849998474121094],
#                     [0.5844999790191651, 0.37849998474121094],
#                     [0.5844999790191651, 0.37849998474121094],
#                     [0.5804999828338623, 0.37849998474121094],
#                     [0.5804999828338623, 0.37849998474121094],
#                     [0.5804999828338623, 0.37849998474121094],
#                     [0.5804999828338623, 0.3714999834696452],
#                     [0.5804999828338623, 0.3714999834696452],
#                     [0.5804999828338623, 0.35949999491373696],
#                     [0.5804999828338623, 0.35949999491373696],
#                     [0.5804999828338623, 0.3504999796549479],
#                     [0.5804999828338623, 0.3504999796549479],
#                     [0.5804999828338623, 0.34149999618530275],
#                     [0.5804999828338623, 0.34149999618530275],
#                     [0.5804999828338623, 0.334499994913737],
#                     [0.5804999828338623, 0.334499994913737],
#                     [0.5804999828338623, 0.32749999364217125],
#                     [0.5804999828338623, 0.32749999364217125],
#                     [0.5804999828338623, 0.3174999872843424],
#                     [0.5804999828338623, 0.3174999872843424],
#                     [0.5804999828338623, 0.30649998982747395],
#                     [0.5804999828338623, 0.30649998982747395],
#                     [0.5804999828338623, 0.2964999834696452],
#                     [0.5804999828338623, 0.2964999834696452],
#                     [0.5804999828338623, 0.2875],
#                     [0.5804999828338623, 0.2875],
#                     [0.5804999828338623, 0.2734999974568685],
#                     [0.5804999828338623, 0.2734999974568685],
#                     [0.5804999828338623, 0.2634999910990397],
#                     [0.5804999828338623, 0.2634999910990397],
#                 ],
#                 [
#                     [0.5264999866485596, 0.6604999542236328],
#                     [0.5335000038146973, 0.6604999542236328],
#                     [0.5335000038146973, 0.6604999542236328],
#                     [0.5424999713897705, 0.6604999542236328],
#                     [0.5424999713897705, 0.6604999542236328],
#                     [0.5494999885559082, 0.6604999542236328],
#                     [0.5494999885559082, 0.6674999872843425],
#                     [0.5494999885559082, 0.6674999872843425],
#                     [0.5494999885559082, 0.6795000076293946],
#                     [0.5494999885559082, 0.6795000076293946],
#                     [0.5494999885559082, 0.693500010172526],
#                     [0.5494999885559082, 0.693500010172526],
#                     [0.5494999885559082, 0.7075000127156575],
#                     [0.5494999885559082, 0.7075000127156575],
#                     [0.5494999885559082, 0.721500015258789],
#                     [0.5494999885559082, 0.721500015258789],
#                     [0.5494999885559082, 0.7354999542236328],
#                     [0.5494999885559082, 0.7354999542236328],
#                     [0.5494999885559082, 0.7494999567667643],
#                     [0.5494999885559082, 0.7494999567667643],
#                     [0.5494999885559082, 0.7614999771118164],
#                     [0.5494999885559082, 0.7614999771118164],
#                     [0.5494999885559082, 0.7754999796549479],
#                     [0.5494999885559082, 0.7754999796549479],
#                     [0.5494999885559082, 0.7894999821980794],
#                     [0.5494999885559082, 0.7894999821980794],
#                     [0.5494999885559082, 0.803499984741211],
#                     [0.5494999885559082, 0.803499984741211],
#                     [0.5494999885559082, 0.8174999872843425],
#                     [0.5494999885559082, 0.8174999872843425],
#                     [0.5494999885559082, 0.8295000076293946],
#                     [0.5494999885559082, 0.8295000076293946],
#                     [0.5494999885559082, 0.8435000101725261],
#                     [0.5494999885559082, 0.8435000101725261],
#                     [0.5494999885559082, 0.8554999669392903],
#                     [0.5494999885559082, 0.8554999669392903],
#                     [0.5494999885559082, 0.8625],
#                     [0.5424999713897705, 0.8625],
#                     [0.5424999713897705, 0.8625],
#                     [0.5375, 0.8625],
#                     [0.5375, 0.8625],
#                     [0.5335000038146973, 0.8625],
#                     [0.5335000038146973, 0.8554999669392903],
#                     [0.5335000038146973, 0.8554999669392903],
#                     [0.5335000038146973, 0.8435000101725261],
#                     [0.5335000038146973, 0.8435000101725261],
#                     [0.5335000038146973, 0.8295000076293946],
#                     [0.5335000038146973, 0.8295000076293946],
#                     [0.5335000038146973, 0.815500005086263],
#                     [0.5335000038146973, 0.815500005086263],
#                     [0.5335000038146973, 0.8015000025431315],
#                     [0.5335000038146973, 0.8015000025431315],
#                     [0.5335000038146973, 0.7894999821980794],
#                     [0.5335000038146973, 0.7894999821980794],
#                     [0.5335000038146973, 0.7754999796549479],
#                     [0.5335000038146973, 0.7754999796549479],
#                     [0.5335000038146973, 0.7614999771118164],
#                     [0.5335000038146973, 0.7614999771118164],
#                     [0.5335000038146973, 0.7494999567667643],
#                     [0.5335000038146973, 0.7494999567667643],
#                     [0.5335000038146973, 0.7354999542236328],
#                     [0.5335000038146973, 0.7354999542236328],
#                     [0.5335000038146973, 0.721500015258789],
#                     [0.5335000038146973, 0.721500015258789],
#                     [0.5335000038146973, 0.7075000127156575],
#                     [0.5335000038146973, 0.7075000127156575],
#                     [0.5335000038146973, 0.6954999923706054],
#                     [0.5335000038146973, 0.6954999923706054],
#                     [0.5335000038146973, 0.681499989827474],
#                     [0.5335000038146973, 0.681499989827474],
#                     [0.5335000038146973, 0.6674999872843425],
#                     [0.5264999866485596, 0.6674999872843425],
#                 ],
#             ],
#             'confidence': None,
#             'index': None,
#             'closed': True,
#             'filled': True,
#         }>,
#     ],
# }>

# %% [markdown]
# # OCR
#
# The Florence2 OCR (Optical Character Recognition) operator can extract text from images in two modes:
#
# 1. **Basic OCR** - Extracts text from the image
#
# 2. **Region-based OCR** - Extracts text and stores the region information for where the text was found by setting `store_region_info=True`
#
# This operator is useful for extracting text content from images, with the option to also capture the location information of where the text appears in the image when needed.
#
# > **Note:** If there is no text in the image then the model will output irrelevant values!
#
# You can run the operator like this:

# %%
import fiftyone.operators as foo

MODEL_PATH ="microsoft/Florence-2-base-ft"

florence2_ocr = foo.get_operator("@jacobmarks/florence2/ocr_with_florence2")

# %%
await florence2_ocr(
    smol_ds,
    model_path=MODEL_PATH,
    store_region_info=True,
    output_field="ocr_regions",
    delegate=True
)

# %%
smol_ds.first()['ocr_regions']
# Out:
# <Detections: {
#     'detections': [
#         <Detection: {
#             'id': '67e1ce70b161a758312e0e87',
#             'attributes': {},
#             'tags': [],
#             'label': '</s>٢٠١٠ ٠٠ ا٠ ب٠اى٠ ما١ ٠ ١١ بواكاف٠ماق با٢ برى باءى ي٠جى للى مانى الجمان بجان يجوان ماماران الحمامة الصوارية يولام الخامية المحانية لحلاية ماولية والحى والمايل الأحة اللهارة العلان والله ماروة الكلار الملاور الشرام ماير الفية علاه الزاموة فيلا مللا كامل المعامد الطايمة ادامادة الاسلا المولله الماعليم المدام ييلل القطاديةة امجادلة الوجلا عامفة ال الماوية',
#             'bounding_box': [
#                 0.0004999999888241291,
#                 0.9994999567667643,
#                 0.998999988567084,
#                 0.0,
#             ],
#             'mask': None,
#             'mask_path': None,
#             'confidence': None,
#             'index': None,
#         }>,
#     ],
# }>

# %%
await florence2_ocr(
    smol_ds,
    model_path=MODEL_PATH,
    store_region_info=False,
    output_field="ocr",
    delegate=True
)

# %%
smol_ds.first()['ocr']
# Out:
# '1'
