# %%
import sys
sys.path.append(".")
from florence2 import Florence2, run_florence2_model

# %%
import fiftyone as fo
import fiftyone.zoo as foz

dataset = fo.load_dataset("quickstart")

# %%
run_florence2_model(
    dataset,
    operation="caption",
    output_field="florence_caption",
    )

# %%
run_florence2_model(
    dataset,
    operation="phrase_grounding",
    caption_field="florence_caption",
    output_field="florence_phrase_grounding",
    )

# %%
dataset
# Out:
# Name:        quickstart
# Media type:  image
# Num samples: 200
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:                        fiftyone.core.fields.ObjectIdField
#     filepath:                  fiftyone.core.fields.StringField
#     tags:                      fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:                  fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     created_at:                fiftyone.core.fields.DateTimeField
#     last_modified_at:          fiftyone.core.fields.DateTimeField
#     ground_truth:              fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     uniqueness:                fiftyone.core.fields.FloatField
#     predictions:               fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     florence_caption:          fiftyone.core.fields.StringField
#     florence_phrase_grounding: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)

# %%
dataset.first()
# Out:
# <Sample: {
#     'id': '67db07ee98dc9f365f3d5769',
#     'media_type': 'image',
#     'filepath': '/home/harpreet/fiftyone/quickstart/data/000880.jpg',
#     'tags': ['validation'],
#     'metadata': None,
#     'created_at': datetime.datetime(2025, 3, 19, 18, 7, 42, 633000),
#     'last_modified_at': datetime.datetime(2025, 3, 20, 21, 51, 18, 317215),
#     'ground_truth': <Detections: {
#         'detections': [
#             <Detection: {
#                 'id': '5f452471ef00e6374aac53c8',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'bird',
#                 'bounding_box': [0.21084375, 0.0034375, 0.46190625, 0.9442083333333334],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'area': 73790.37944999996,
#                 'iscrowd': 0.0,
#             }>,
#             <Detection: {
#                 'id': '5f452471ef00e6374aac53c9',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'bird',
#                 'bounding_box': [0.74946875, 0.489375, 0.2164375, 0.23183333333333334],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'area': 3935.7593000000006,
#                 'iscrowd': 0.0,
#             }>,
#             <Detection: {
#                 'id': '5f452471ef00e6374aac53ca',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'bird',
#                 'bounding_box': [
#                     0.044234375,
#                     0.5282083333333333,
#                     0.151390625,
#                     0.14145833333333335,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'area': 4827.32605,
#                 'iscrowd': 0.0,
#             }>,
#         ],
#     }>,
#     'uniqueness': 0.8175834390151201,
#     'predictions': <Detections: {
#         'detections': [
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad9394',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'bird',
#                 'bounding_box': [
#                     0.22192673683166503,
#                     0.06093006531397502,
#                     0.4808845520019531,
#                     0.8937615712483724,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.9750854969024658,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad9395',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'bird',
#                 'bounding_box': [
#                     0.3962469816207886,
#                     0.006943931678930918,
#                     0.27418792247772217,
#                     0.46793556213378906,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.759726881980896,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad9396',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'bird',
#                 'bounding_box': [
#                     0.02506386339664459,
#                     0.548487663269043,
#                     0.16438478231430054,
#                     0.16736234029134114,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.6569182276725769,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad9397',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'bird',
#                 'bounding_box': [
#                     0.4889101028442383,
#                     0.009576511383056641,
#                     0.13802199363708495,
#                     0.2093157132466634,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.2359301745891571,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad9398',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'elephant',
#                 'bounding_box': [
#                     0.015171945095062256,
#                     0.555288823445638,
#                     0.1813342332839966,
#                     0.15938574473063152,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.221974179148674,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad9399',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'bear',
#                 'bounding_box': [
#                     0.017808181047439576,
#                     0.5488224665323893,
#                     0.17450940608978271,
#                     0.16891117095947267,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.1965726613998413,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad939a',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'elephant',
#                 'bounding_box': [
#                     0.16558188199996948,
#                     0.5723957061767578,
#                     0.09993256330490112,
#                     0.10098978678385416,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.18904592096805573,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad939b',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'sheep',
#                 'bounding_box': [
#                     0.213010573387146,
#                     0.05354320605595907,
#                     0.5153374671936035,
#                     0.8933518091837566,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.11480894684791565,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad939c',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'bird',
#                 'bounding_box': [
#                     0.29751906394958494,
#                     0.010790024201075237,
#                     0.3315577507019043,
#                     0.34026527404785156,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.11089690029621124,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad939d',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'elephant',
#                 'bounding_box': [
#                     0.08351035118103027,
#                     0.5574632008870443,
#                     0.18209288120269776,
#                     0.1426785151163737,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.0971052274107933,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad939e',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'bird',
#                 'bounding_box': [
#                     0.4461814880371094,
#                     0.0007838249827424685,
#                     0.209574556350708,
#                     0.309667714436849,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.08403241634368896,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad939f',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'bird',
#                 'bounding_box': [
#                     0.5395165920257569,
#                     0.034476550420125325,
#                     0.07703280448913574,
#                     0.16296254793802897,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.07699568569660187,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad93a0',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'bear',
#                 'bounding_box': [
#                     0.217216157913208,
#                     0.05954849322636922,
#                     0.49451656341552735,
#                     0.8721434275309244,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.058097004890441895,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '5f452c60ef00e6374aad93a1',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'sheep',
#                 'bounding_box': [
#                     0.018094074726104737,
#                     0.5562847137451172,
#                     0.17362892627716064,
#                     0.15742950439453124,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.0519101656973362,
#                 'index': None,
#             }>,
#         ],
#     }>,
#     'florence_caption': 'A chicken standing in the middle of a grassy field.',
#     'florence_phrase_grounding': <Detections: {
#         'detections': [
#             <Detection: {
#                 'id': '67dc8dd6cec7dbb4c97bcedf',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'A chicken standing',
#                 'bounding_box': [
#                     0.22349998950958253,
#                     0.0004999999888241291,
#                     0.4470000028610229,
#                     0.9229999974680444,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#             }>,
#         ],
#     }>,
# }>
